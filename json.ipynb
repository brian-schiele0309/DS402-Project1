# %%
data = {'valuationsI1':[
    {"Indiv":"a1","g1":10,"g2":20,"g3":30},
    {"Indiv":"a2","g1":15,"g2":5,"g3":10},
    {"Indiv":"a3","g1":2,"g2":10,"g3":1}], 'allocationsI1': [
    {"a1":"g1","a2":"g2","a3":"g3","Payoff":"(10,5,1)","Notions":"EF"},
    {"a1":"g1","a2":"g3","a3":"g2","Payoff":"(10,10,10)","Notions":"EQ"},
    {"a1":"NA","a2":"g2","a3":"g1,g3","Payoff":"(0,5,3)","Notions":"USW"}
  ],
  'valuationsI2': [{"Indiv":"a1","g1":12,"g2":33,"g3":17},
    {"Indiv":"a2","g1":20,"g2":3,"g3":12},
    {"Indiv":"a3","g1":9,"g2":12,"g3":1}], 'allocationsI2': [{"a1":"g1","a2":"g2","a3":"g3","Payoff":"(12,3,1)","Notions":"EF"},
    {"a1":"NA","a2":"g2","a3":"g1,g3","Payoff":"(0,3,10)","Notions":"USW"},
    {"a1":"g1","a2":"g3","a3":"g2","Payoff":"(12,12,12)","Notions":"EQ"}
    ],
    'valuationsI3': [{"Indiv":"a1","g1":4,"g2":3,"g3":2, 'g4':1},
    {"Indiv":"a2","g1":12,"g2":4,"g3":7,'g4':5},
    {"Indiv":"a3","g1":1,"g2":2,"g3":15,'g4':7}], 'allocationsI3': [{"a1":"g4,g3","a2":"g2","a3":"g1","Payoff":"(3,4,1)","Notions":"EF"},
    {"a1":"g1,g2","a2":"g4","a3":"g3","Payoff":"(7,7,7)","Notions":"EQ"},
    {"a1":"g3,g4","a2":"NA","a3":"g1,g2","Payoff":"(3,0,3)","Notions":"USW"}
    ],
    'valuationsI4': [{"Indiv":"a1","g1":17,"g2":5,"g3":3,'g4':12},
    {"Indiv":"a2","g1":15,"g2":25,"g3":40,'g4':13},
    {"Indiv":"a3","g1":12,"g2":15,"g3":4,'g4':30}], 'allocationsI4': [{"a1":"g2,g3","a2":"g4","a3":"g1","Payoff":"(8,13,12)","Notions":"EF"},
    {"a1":"g3,g4","a2":"g1","a3":"g2","Payoff":"(15,15,15)","Notions":"EQ"},
    {"a1":"g2,g3,g4","a2":"NA","a3":"g1","Payoff":"(20,0,12)","Notions":"USW"}
    ],
    'valuationsI5': [{"Indiv":"a1","g1":4,"g2":15,"g3":25,'g4':20,'g5':35},
    {"Indiv":"a2","g1":20,"g2":30,"g3":15,'g4':13,'g5':2},
    {"Indiv":"a3","g1":35,"g2":20,"g3":17,'g4':24,'g5':35}], 'allocationsI5': [{"a1":"g1,g2","a2":"g4,g5","a3":"g3","Payoff":"(19,15,17)","Notions":"EF"},
    {"a1":"g1,g2","a2":"g3,g4.g5","a3":"NA","Payoff":"(19,30,0)","Notions":"USW"},
    {"a1":"g2,g4","a2":"g1,g3","a3":"g5","Payoff":"(35,35,35)","Notions":"EQ"}
    ],
    'valuationsI6': [{"Indiv":"a1","g1":17,"g2":10,"g3":14,'g4':15,'g5':7},
    {"Indiv":"a2","g1":14,"g2":16,"g3":12,'g4':7,'g5':9},
    {"Indiv":"a3","g1":18,"g2":21,"g3":24,'g4':12,'g5':13}], 'allocationsI5': [{"a1":"g5,g2","a2":"g4,g3","a3":"g1","Payoff":"(17,19,18)","Notions":"EF"},
    {"a1":"g3,g5","a2":"g1,g4","a3":"g2","Payoff":"(21,21,21)","Notions":"EQ"},
    {"a1":"g2,g5","a2":"g1,g3,g4","a3":"NA","Payoff":"(17,33,0)","Notions":"USW"}
    ],
    'valuationsI7': [{"Indiv":"a1","g1":12,"g2":17,"g3":9,'g4':10},
    {"Indiv":"a2","g1":15,"g2":5,"g3":12,'g4':7},
    {"Indiv":"a3","g1":7,"g2":10,"g3":9,'g4':12},
    {"Indiv":"a4","g1":15,"g2":12,"g3":13,'g4':8}], 'allocationsI7': [{"a1":"g3","a2":"g2","a3":"g1",'a4':'g4',"Payoff":"(9,5,7,8)","Notions":"EF"},
    {"a1":"g3","a2":"g2,g4","a3":"g1",'a4':'NA',"Payoff":"(9,12,7,0)","Notions":"USW"},
    {"a1":"g1","a2":"g3","a3":"g4",'a4':'g2',"Payoff":"(12,12,12,12)","Notions":"EQ"}
    ],
    'valuationsI8': [{"Indiv":"a1","g1":20,"g2":30,"g3":27,'g4':24},
    {"Indiv":"a2","g1":25,"g2":22,"g3":24,'g4':20},
    {"Indiv":"a3","g1":30,"g2":24,"g3":20,'g4':25},
    {"Indiv":"a4","g1":24,"g2":24,"g3":29,'g4':26}], 'allocationsI8': [{"a1":"g1","a2":"g4","a3":"g3",'a4':'g2',"Payoff":"(20,20,20,24)","Notions":"EF"},
    {"a1":"g1","a2":"g2,g4","a3":"g3",'a4':'NA',"Payoff":"(20,42,20,0)","Notions":"USW"},
    {"a1":"g4","a2":"g3","a3":"g2",'a4':'g1',"Payoff":"(24,24,24,24)","Notions":"EQ"}
    ],
    'valuationsI9': [{"Indiv":"a1","g1":10,"g2":5,"g3":3,'g4':6,'g5':1},
    {"Indiv":"a2","g1":9,"g2":6,"g3":7,'g4':4,'g5':10},
    {"Indiv":"a3","g1":7,"g2":2,"g3":9,'g4':8,'g5':5},
    {"Indiv":"a4","g1":1,"g2":7,"g3":2,'g4':3,'g5':9}], 'allocationsI9': [{"a1":"g5,g3","a2":"g4","a3":"g1",'a4':'g1',"Payoff":"(4,4,2,1)","Notions":"EF"},
    {"a1":"g5","a2":"NA","a3":"g2",'a4':'g1,g3,g4',"Payoff":"(1,0,2,6)","Notions":"USW"},
    {"a1":"g4,g5","a2":"g3","a3":"g1",'a4':'g2',"Payoff":"(7,7,7,7)","Notions":"EQ"}
    ],
    'valuationsI10': [{"Indiv":"a1","g1":3,"g2":6,"g3":7,'g4':2,'g5':5},
    {"Indiv":"a2","g1":5,"g2":4,"g3":6,'g4':8,'g5':3},
    {"Indiv":"a3","g1":6,"g2":4,"g3":1,'g4':3,'g5':9},
    {"Indiv":"a4","g1":8,"g2":1,"g3":3,'g4':4,'g5':2}], 'allocationsI10': [{"a1":"g1,g4","a2":"g5","a3":"g3",'a4':'g2',"Payoff":"(5,3,1,1)","Notions":"EF"},
    {"a1":"g1,g4","a2":"NA","a3":"g3",'a4':'g2,g5',"Payoff":"(5,0,1,3)","Notions":"USW"},
    {"a1":"g2","a2":"g3","a3":"g1",'a4':'g4,g5',"Payoff":"(6,6,6,6)","Notions":"EQ"}
    ],
    'valuationsI11': [{"Indiv":"a1","g1":3,"g2":6,"g3":9,'g4':5,'g5':1},
    {"Indiv":"a2","g1":5,"g2":4,"g3":8,'g4':2,'g5':6},
    {"Indiv":"a3","g1":9,"g2":10,"g3":1,'g4':3,'g5':5},
    {"Indiv":"a4","g1":6,"g2":5,"g3":7,'g4':8,'g5':6},
    {"Indiv":"a5","g1":1,"g2":8,"g3":5,'g4':6,'g5':9}], 'allocationsI11': [{"a1":"g5","a2":"g4","a3":"g3",'a4':'g2','a5':'g1',"Payoff":"(1,2,1,5,1)","Notions":"EF"},
    {"a1":"g4","a2":"g1","a3":"g5",'a4':'g2','a5':'g3',"Payoff":"(5,5,5,5,5)","Notions":"EQ"},
    {"a1":"g5","a2":"g2,g4","a3":"g3",'a4':'NA','a5':'g1',"Payoff":"(1,6,1,0,1)","Notions":"USW"}
    ],
    'valuationsI12': [{"Indiv":"a1","g1":7,"g2":9,"g3":4,'g4':2,'g5':1},
    {"Indiv":"a2","g1":6,"g2":4,"g3":5,'g4':3,'g5':9},
    {"Indiv":"a3","g1":4,"g2":10,"g3":2,'g4':5,'g5':8},
    {"Indiv":"a4","g1":3,"g2":7,"g3":6,'g4':8,'g5':4},
    {"Indiv":"a5","g1":9,"g2":2,"g3":3,'g4':4,'g5':5}], 'allocationsI12': [{"a1":"g5","a2":"g4","a3":"g3",'a4':'g1','a5':'g2',"Payoff":"(1,3,2,3,2)","Notions":"EF"},
    {"a1":"g3","a2":"g2","a3":"g1",'a4':'g5','a5':'g4',"Payoff":"(4,4,4,4,4)","Notions":"EQ"},
    {"a1":"g4,g5","a2":"NA","a3":"g3",'a4':'g1','a5':'g2',"Payoff":"(3,0,2,3,2)","Notions":"USW"}
    ],
    'valuationsI13': [{"Indiv":"a1","g1":4,"g2":6,"g3":4,'g4':8,'g5':10,'g6':3},
    {"Indiv":"a2","g1":5,"g2":7,"g3":9,'g4':2,'g5':6,'g6':5},
    {"Indiv":"a3","g1":4,"g2":2,"g3":5,'g4':6,'g5':2,'g6':6}], 'allocationsI13': [{"a1":"g3,g6","a2":"g1,g4","a3":"g2,g5","Payoff":"(7,7,4)","Notions":"EF"},
    {"a1":"g1,g3","a2":"g4,g5","a3":"g2,g6","Payoff":"(8,8,8)","Notions":"EQ"},
    {"a1":"g1,g3,g6","a2":"g4","a3":"g2,g5","Payoff":"(11,2,4)","Notions":"USW"}
    ],
    'valuationsI14': [{"Indiv":"a1","g1":12,"g2":7,"g3":9,'g4':3,'g5':15,'g6':4},
    {"Indiv":"a2","g1":1,"g2":5,"g3":10,'g4':2,'g5':2,'g6':8},
    {"Indiv":"a3","g1":4,"g2":2,"g3":3,'g4':6,'g5':7,'g6':9}], 'allocationsI14': [{"a1":"g4,g6","a2":"g1,g5","a3":"g2,g3","Payoff":"(7,3,5)","Notions":"EF"},
    {"a1":"g4,g6","a2":"g2,g5","a3":"g1,g3","Payoff":"(7,7,7)","Notions":"EQ"},
    {"a1":"g6","a2":"g1,g4,g5","a3":"g2,g3","Payoff":"(4,5,5)","Notions":"USW"}
    ],
    'valuationsI15': [{"Indiv":"a1","g1":5,"g2":8,"g3":7,'g4':9,'g5':12,'g6':1},
    {"Indiv":"a2","g1":8,"g2":8,"g3":2,'g4':14,'g5':10,'g6':10},
    {"Indiv":"a3","g1":11,"g2":7,"g3":3,'g4':6,'g5':2,'g6':4},
    {"Indiv":"a4","g1":5,"g2":8,"g3":12,'g4':4,'g5':8,'g6':7}], 'allocationsI15': [{"a1":"g1,g6","a2":"g2,g3","a3":"g5",'a4':'g4',"Payoff":"(6,10,3,4)","Notions":"EF"},
    {"a1":"g6,g3","a2":"g1","a3":"g4,g5",'a4':'g2',"Payoff":"(8,8,8,8)","Notions":"EQ"},
    {"a1":"g1,g6","a2":"g3","a3":"g2,g5",'a4':'g4',"Payoff":"(6,2,9,4)","Notions":"USW"}
    ],
    'valuationsI16': [{"Indiv":"a1","g1":4,"g2":2,"g3":7,'g4':8,'g5':9,'g6':7},
    {"Indiv":"a2","g1":3,"g2":6,"g3":1,'g4':8,'g5':3,'g6':9},
    {"Indiv":"a3","g1":10,"g2":8,"g3":6,'g4':5,'g5':11,'g6':7},
    {"Indiv":"a4","g1":13,"g2":6,"g3":5,'g4':4,'g5':10,'g6':3}], 'allocationsI16': [{"a1":"g1,g2","a2":"g5,g3","a3":"g4",'a4':'g6',"Payoff":"(6,4,5,3)","Notions":"EF"},
    {"a1":"g2,g4","a2":"g3,g6","a3":"g1",'a4':'g5',"Payoff":"(10,10,10,10)","Notions":"EQ"},
    {"a1":"g2","a2":"g1,g3,g5","a3":"NA",'a4':'g4,g6',"Payoff":"(2,7,0,7)","Notions":"USW"}
    ],
    'valuationsI17': [{"Indiv":"a1","g1":9,"g2":7,"g3":2,'g4':5,'g5':11,'g6':14},
    {"Indiv":"a2","g1":6,"g2":3,"g3":4,'g4':12,'g5':2,'g6':7},
    {"Indiv":"a3","g1":9,"g2":2,"g3":7,'g4':4,'g5':15,'g6':5},
    {"Indiv":"a4","g1":7,"g2":8,"g3":4,'g4':9,'g5':7,'g6':3},
    {"Indiv":"a5","g1":1,"g2":9,"g3":7,'g4':3,'g5':4,'g6':8}], 'allocationsI17': [{"a1":"g3,g4","a2":"g5","a3":"g2",'a4':'g6','a5':'g1',"Payoff":"(7,2,2,3,1)","Notions":"EF"},
    {"a1":"g2","a2":"g6","a3":"g3",'a4':'g1','a5':'g4,g5',"Payoff":"(7,7,7,7,7)","Notions":"EQ"},
    {"a1":"g3","a2":"g5","a3":"g2",'a4':'g5,g6','a5':'g1,g4',"Payoff":"(2,2,2,3,4)","Notions":"USW"}
    ],
    'valuationsI18': [{"Indiv":"a1","g1":13,"g2":7,"g3":6,'g4':4,'g5':18,'g6':2},
    {"Indiv":"a2","g1":6,"g2":1,"g3":6,'g4':2,'g5':11,'g6':9},
    {"Indiv":"a3","g1":7,"g2":3,"g3":2,'g4':4,'g5':3,'g6':8},
    {"Indiv":"a4","g1":1,"g2":3,"g3":5,'g4':8,'g5':16,'g6':6},
    {"Indiv":"a5","g1":3,"g2":11,"g3":9,'g4':6,'g5':2,'g6':4}], 'allocationsI18': [{"a1":"g4,g6","a2":"g2","a3":"g3",'a4':'g1','a5':'g5',"Payoff":"(6,1,2,1,2)","Notions":"EF"},
    {"a1":"g3","a2":"g1","a3":"g2,g5",'a4':'g6','a5':'g4',"Payoff":"(6,6,6,6,6)","Notions":"EQ"},
    {"a1":"g6","a2":"g2,g4","a3":"g3",'a4':'g1','a5':'g5',"Payoff":"(2,3,2,1,2)","Notions":"USW"}
    ]}

# %%
import json

with open("instances_and_allocations.json", "w") as f:
    json.dump(data, f, indent=4)
